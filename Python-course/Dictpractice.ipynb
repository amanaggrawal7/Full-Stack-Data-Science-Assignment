# %%
l = [2,4,2,3]

# %%
l
# Out:
# [2, 4, 2, 3]

# %%
d1 = {"name":"aman", "age": 25}

# %%
d2 = {"Lname": "Anshu", "ahe":21}

# %%
d1.update(d2)

# %%
d1
# Out:
# {'name': 'aman', 'age': 25, 'Lname': 'Anshu', 'ahe': 21}

# %%
for i in enumerate(d1):
    print(i)
# Out:
# (0, 'name')
# (1, 'age')
# (2, 'Lname')
# (3, 'ahe')

# %%
x = {}

# %%
type(x)
# Out:
# dict

# %%
d1 = {"Hello"}

# %%
type(d1
    )
# Out:
# set

# %%
d1 = {"name": "aman", "age" : 54}

# %%
d1
# Out:
# {'name': 'aman', 'age': 54}

# %%
type(d1)
# Out:
# dict

# %%
d1["name"]
# Out:
# 'aman'

# %%
d1 = {"name": "aman", "person" : {"Lname" : "kumar", "address": "JP nager"}, "Road": "jp"}

# %%
d1
# Out:
# {'name': 'aman',
#  'person': {'Lname': 'kumar', 'address': 'JP nager'},
#  'Road': 'jp'}

# %%
d1["person"]["Lname"]
# Out:
# 'kumar'

# %%
d1 = {"name": "aman", "person" : {"Lname" : "kumar", "address": "JP nager"}, "Road": "jp", "value": [2,3,4,5,6], "tuple": (2,33,4)}

# %%
d1
# Out:
# {'name': 'aman',
#  'person': {'Lname': 'kumar', 'address': 'JP nager'},
#  'Road': 'jp',
#  'value': [2, 3, 4, 5, 6],
#  'tuple': (2, 33, 4)}

# %%
type(d1["value"])
# Out:
# list

# %%
d1["value"][3]
# Out:
# 5

# %%
d1["person"]
# Out:
# {'Lname': 'kumar', 'address': 'JP nager'}

# %%
d2 = {"hello": "Good mornig"}

# %%
d1 + d2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 d1 + d2
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
d1.update(d2)

# %%
d1
# Out:
# {'name': 'aman',
#  'person': {'Lname': 'kumar', 'address': 'JP nager'},
#  'Road': 'jp',
#  'value': [2, 3, 4, 5, 6],
#  'tuple': (2, 33, 4),
#  'hello': 'Good mornig'}

# %%
d1["public"] = 5678

# %%
d1
# Out:
# {'name': 'aman',
#  'person': {'Lname': 'kumar', 'address': 'JP nager'},
#  'Road': 'jp',
#  'value': [2, 3, 4, 5, 6],
#  'tuple': (2, 33, 4),
#  'hello': 'Good mornig',
#  'public': 5678}

# %%
d1.keys()
# Out:
# dict_keys(['name', 'person', 'Road', 'value', 'tuple', 'hello', 'public'])

# %%
d1.values()
# Out:
# dict_values(['aman', {'Lname': 'kumar', 'address': 'JP nager'}, 'jp', [2, 3, 4, 5, 6], (2, 33, 4), 'Good mornig', 5678])

# %%
d1.items()
# Out:
# dict_items([('name', 'aman'), ('person', {'Lname': 'kumar', 'address': 'JP nager'}), ('Road', 'jp'), ('value', [2, 3, 4, 5, 6]), ('tuple', (2, 33, 4)), ('hello', 'Good mornig'), ('public', 5678)])

# %%
d1
# Out:
# {'name': 'aman',
#  'person': {'Lname': 'kumar', 'address': 'JP nager'},
#  'Road': 'jp',
#  'value': [2, 3, 4, 5, 6],
#  'tuple': (2, 33, 4),
#  'hello': 'Good mornig',
#  'public': 5678}

# %%
"aman" in d1
# Out:
# False

# %%
"hello" in d1
# Out:
# True

# %%
for i in d1.keys():
    print(i)
# Out:
# name
# person
# Road
# value
# tuple
# hello
# public

# %%
for i in d1.values():
    print(i)
# Out:
# aman
# {'Lname': 'kumar', 'address': 'JP nager'}
# jp
# [2, 3, 4, 5, 6]
# (2, 33, 4)
# Good mornig
# 5678

# %%
for i in d1.items():
    print(i)
# Out:
# ('name', 'aman')
# ('person', {'Lname': 'kumar', 'address': 'JP nager'})
# ('Road', 'jp')
# ('value', [2, 3, 4, 5, 6])
# ('tuple', (2, 33, 4))
# ('hello', 'Good mornig')
# ('public', 5678)

# %%
d1.keys()
# Out:
# dict_keys(['name', 'person', 'Road', 'value', 'tuple', 'hello', 'public'])

# %%
d1.values()
# Out:
# dict_values(['aman', {'Lname': 'kumar', 'address': 'JP nager'}, 'jp', [2, 3, 4, 5, 6], (2, 33, 4), 'Good mornig', 5678])

# %%
d1.items()
# Out:
# dict_items([('name', 'aman'), ('person', {'Lname': 'kumar', 'address': 'JP nager'}), ('Road', 'jp'), ('value', [2, 3, 4, 5, 6]), ('tuple', (2, 33, 4)), ('hello', 'Good mornig'), ('public', 5678)])

# %%
for i in d1.keys():
    print(type(d1[i]))
# Out:
# <class 'str'>
# <class 'dict'>
# <class 'str'>
# <class 'list'>
# <class 'tuple'>
# <class 'str'>
# <class 'int'>

# %%
for i in d1:
    print(type(d1[i]))
# Out:
# <class 'str'>
# <class 'dict'>
# <class 'str'>
# <class 'list'>
# <class 'tuple'>
# <class 'str'>
# <class 'int'>

# %%
d1.items()
# Out:
# dict_items([('name', 'aman'), ('person', {'Lname': 'kumar', 'address': 'JP nager'}), ('Road', 'jp'), ('value', [2, 3, 4, 5, 6]), ('tuple', (2, 33, 4)), ('hello', 'Good mornig'), ('public', 5678)])

# %%
for i in d1.items():
    print(i[1])
# Out:
# aman
# {'Lname': 'kumar', 'address': 'JP nager'}
# jp
# [2, 3, 4, 5, 6]
# (2, 33, 4)
# Good mornig
# 5678

# %%
d3 = {[2,2,2]:"aman"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 d3 = {[2,2,2]:"aman"}
#
# TypeError: unhashable type: 'list'

# %%
d3 = {(2,2,2,2): "aman"}

# %%
d3
# Out:
# {(2, 2, 2, 2): 'aman'}

# %%
d3[(2,2,2,2)]
# Out:
# 'aman'

# %%
d3 = {{"person": 24}:"aman", "hello": "wo"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 d3 = {{"person": 24}:"aman", "hello": "wo"}
#
# TypeError: unhashable type: 'dict'

# %%
d2
# Out:
# {'hello': 'Good mornig'}

# %%
d1
# Out:
# {'name': 'aman',
#  'person': {'Lname': 'kumar', 'address': 'JP nager'},
#  'Road': 'jp',
#  'value': [2, 3, 4, 5, 6],
#  'tuple': (2, 33, 4),
#  'hello': 'Good mornig',
#  'public': 5678}

# %%
d3
# Out:
# {(2, 2, 2, 2): 'aman'}

# %%
len(d1)
# Out:
# 7

# %%
len(d2)
# Out:
# 1

# %%
e = {11:{23,3,2,2,2}}

# %%
e
# Out:
# {11: {2, 3, 23}}

# %%
e[11]
# Out:
# {2, 3, 23}

# %%
type(e[11])
# Out:
# set

# %%
(e[11])
# Out:
# {2, 3, 23}

# %%
e[11].remove(2)

# %%
e[11]
# Out:
# {3, 23}

# %%
a = input("Enter a paragraph")
b = a.split()
b
# Out:
# Enter a paragraph enter a paragraph India, officially the Republic of India,[j][20] is a country in South Asia. It is the seventh-largest country by area; the most populous country since 2023;[21] and, since its independence in 1947, the world's most populous democracy.
# ['enter',
#  'a',
#  'paragraph',
#  'India,',
#  'officially',
#  'the',
#  'Republic',
#  'of',
#  'India,[j][20]',
#  'is',
#  'a',
#  'country',
#  'in',
#  'South',
#  'Asia.',
#  'It',
#  'is',
#  'the',
#  'seventh-largest',
#  'country',
#  'by',
#  'area;',
#  'the',
#  'most',
#  'populous',
#  'country',
#  'since',
#  '2023;[21]',
#  'and,',
#  'since',
#  'its',
#  'independence',
#  'in',
#  '1947,',
#  'the',
#  "world's",
#  'most',
#  'populous',
#  'democracy.']

# %%
type(b)
# Out:
# list

# %%
b
# Out:
# ['enter',
#  'a',
#  'paragraph',
#  'India,',
#  'officially',
#  'the',
#  'Republic',
#  'of',
#  'India,[j][20]',
#  'is',
#  'a',
#  'country',
#  'in',
#  'South',
#  'Asia.',
#  'It',
#  'is',
#  'the',
#  'seventh-largest',
#  'country',
#  'by',
#  'area;',
#  'the',
#  'most',
#  'populous',
#  'country',
#  'since',
#  '2023;[21]',
#  'and,',
#  'since',
#  'its',
#  'independence',
#  'in',
#  '1947,',
#  'the',
#  "world's",
#  'most',
#  'populous',
#  'democracy.']

# %%
c = set(b)

# %%
c
# Out:
# {'1947,',
#  '2023;[21]',
#  'Asia.',
#  'India,',
#  'India,[j][20]',
#  'It',
#  'Republic',
#  'South',
#  'a',
#  'and,',
#  'area;',
#  'by',
#  'country',
#  'democracy.',
#  'enter',
#  'in',
#  'independence',
#  'is',
#  'its',
#  'most',
#  'of',
#  'officially',
#  'paragraph',
#  'populous',
#  'seventh-largest',
#  'since',
#  'the',
#  "world's"}

# %%
d = list(c)

# %%
d
# Out:
# ['South',
#  'It',
#  'seventh-largest',
#  'democracy.',
#  'area;',
#  'enter',
#  'paragraph',
#  'Asia.',
#  'India,',
#  'officially',
#  'independence',
#  '1947,',
#  'in',
#  'is',
#  'country',
#  'a',
#  '2023;[21]',
#  'by',
#  'India,[j][20]',
#  'most',
#  'populous',
#  'and,',
#  'its',
#  'since',
#  'the',
#  'Republic',
#  'of',
#  "world's"]

# %%
e = dict.fromkeys(d,"aman")

# %%
e
# Out:
# {'South': 'aman',
#  'It': 'aman',
#  'seventh-largest': 'aman',
#  'democracy.': 'aman',
#  'area;': 'aman',
#  'enter': 'aman',
#  'paragraph': 'aman',
#  'Asia.': 'aman',
#  'India,': 'aman',
#  'officially': 'aman',
#  'independence': 'aman',
#  '1947,': 'aman',
#  'in': 'aman',
#  'is': 'aman',
#  'country': 'aman',
#  'a': 'aman',
#  '2023;[21]': 'aman',
#  'by': 'aman',
#  'India,[j][20]': 'aman',
#  'most': 'aman',
#  'populous': 'aman',
#  'and,': 'aman',
#  'its': 'aman',
#  'since': 'aman',
#  'the': 'aman',
#  'Republic': 'aman',
#  'of': 'aman',
#  "world's": 'aman'}

# %%
e = dict.fromkeys(d,"25")

# %%
e
# Out:
# {'South': '25',
#  'It': '25',
#  'seventh-largest': '25',
#  'democracy.': '25',
#  'area;': '25',
#  'enter': '25',
#  'paragraph': '25',
#  'Asia.': '25',
#  'India,': '25',
#  'officially': '25',
#  'independence': '25',
#  '1947,': '25',
#  'in': '25',
#  'is': '25',
#  'country': '25',
#  'a': '25',
#  '2023;[21]': '25',
#  'by': '25',
#  'India,[j][20]': '25',
#  'most': '25',
#  'populous': '25',
#  'and,': '25',
#  'its': '25',
#  'since': '25',
#  'the': '25',
#  'Republic': '25',
#  'of': '25',
#  "world's": '25'}

# %%
type(e.keys())
# Out:
# dict_keys

# %%
e.values()
# Out:
# dict_values(['25', '25', '25', '25', '25', '25', '25', '25', '25', '25', '25', '25', '25', '25', '25', '25', '25', '25', '25', '25', '25', '25', '25', '25', '25', '25', '25', '25'])

# %%
list(e.values())
# Out:
# ['25',
#  '25',
#  '25',
#  '25',
#  '25',
#  '25',
#  '25',
#  '25',
#  '25',
#  '25',
#  '25',
#  '25',
#  '25',
#  '25',
#  '25',
#  '25',
#  '25',
#  '25',
#  '25',
#  '25',
#  '25',
#  '25',
#  '25',
#  '25',
#  '25',
#  '25',
#  '25',
#  '25']

# %%
tuple(e.keys())
# Out:
# ('South',
#  'It',
#  'seventh-largest',
#  'democracy.',
#  'area;',
#  'enter',
#  'paragraph',
#  'Asia.',
#  'India,',
#  'officially',
#  'independence',
#  '1947,',
#  'in',
#  'is',
#  'country',
#  'a',
#  '2023;[21]',
#  'by',
#  'India,[j][20]',
#  'most',
#  'populous',
#  'and,',
#  'its',
#  'since',
#  'the',
#  'Republic',
#  'of',
#  "world's")

# %%
a = (2,3,4,5,6,7,8,9)
b = dict.fromkeys(a,2)

# %%
b
# Out:
# {2: 2, 3: 2, 4: 2, 5: 2, 6: 2, 7: 2, 8: 2, 9: 2}

# %%
for i in d1:
    print("print a key:", i , " ; value wise : ", d1[i])
# Out:
# print a key: name  ; value wise :  aman
# print a key: person  ; value wise :  {'Lname': 'kumar', 'address': 'JP nager'}
# print a key: Road  ; value wise :  jp
# print a key: value  ; value wise :  [2, 3, 4, 5, 6]
# print a key: tuple  ; value wise :  (2, 33, 4)
# print a key: hello  ; value wise :  Good mornig
# print a key: public  ; value wise :  5678

# %%
"hello" in d1
# Out:
# True

# %%
d1
# Out:
# {'name': 'aman',
#  'person': {'Lname': 'kumar', 'address': 'JP nager'},
#  'Road': 'jp',
#  'value': [2, 3, 4, 5, 6],
#  'tuple': (2, 33, 4),
#  'hello': 'Good mornig',
#  'public': 5678}

# %%
d1 = {'name': 'aman',
 'person': {'Lname': 'kumar', 'address': 'JP nager'},
 'Road': 'jp',
 'value': [2, 3, 4, 5, 6],
 'tuple': (2, 33, 4),
 'hello': 'Good mornig',
 'public': 5678, 'date': 2025}

# %%
for i in d1:
    if i == "date":
        if d1[i] > 2021:
            print("year is fine")
        else:
            d1[i] = 2022
# Out:
# year is fine

# %%
d1
# Out:
# {'name': 'aman',
#  'person': {'Lname': 'kumar', 'address': 'JP nager'},
#  'Road': 'jp',
#  'value': [2, 3, 4, 5, 6],
#  'tuple': (2, 33, 4),
#  'hello': 'Good mornig',
#  'public': 5678,
#  'date': 2025}

# %%
d = {"course":"ineuron", "subject": "full stack development"}

# %%
type(d)
# Out:
# dict

# %%
for i in d:
    print(i)
# Out:
# course
# subject

# %%
for i in d1:
    if i == "date":
        if d1[i] >2028:
            print("year is fine")
        else:
            d[i] = 2090

# %%
d1
# Out:
# {'name': 'aman',
#  'person': {'Lname': 'kumar', 'address': 'JP nager'},
#  'Road': 'jp',
#  'value': [2, 3, 4, 5, 6],
#  'tuple': (2, 33, 4),
#  'hello': 'Good mornig',
#  'public': 5678,
#  'date': 2025}

# %%
for i in d1:
    if i == "date":
        if d1[i] >2028:
            print("year is fine")
        else:
            print("Year is not fine")
            d[i] = 2090
# Out:
# Year is not fine

# %%
for i in d1:
    if i == "date":
        if d1[i] > 2021:
            print("year is fine")
        else:
            d1[i] = 2022
# Out:
# year is fine

# %%
d1
# Out:
# {'name': 'aman',
#  'person': {'Lname': 'kumar', 'address': 'JP nager'},
#  'Road': 'jp',
#  'value': [2, 3, 4, 5, 6],
#  'tuple': (2, 33, 4),
#  'hello': 'Good mornig',
#  'public': 5678,
#  'date': 2025}

# %%
my_dict = {}
for i in range(10)
# Out:
#   Cell In[40], line 2
#     for i in range(10)
#                       ^
# SyntaxError: expected ':'
