# %% [markdown]
# SET:-
# Collection of unique data which is alyways tried to hold distinct element in a collection and it is a case sensitive
# . from set we are not get an orderd data its all illusion

# %%
x = set()

# %%
type(x)
# Out:
# set

# %%
l = [343,434,34,34,34,34,3,4,"aman", "aman","aman"]

# %%
l
# Out:
# [343, 434, 34, 34, 34, 34, 3, 4, 'aman', 'aman', 'aman']

# %%
x = set(l)

# %%
x
# Out:
# {3, 34, 343, 4, 434, 'aman'}

# %%
x  = {112,23,2,32,323,23,2,32,32,32,23}

# %%
x
# Out:
# {2, 23, 32, 112, 323}

# %%
for i in x:
    print(i)
# Out:
# 32
# 112
# 2
# 323
# 23

# %%
32 in x
# Out:
# True

# %%
s = set()

# %%
s
# Out:
# set()

# %%
s.add(23)

# %%
s
# Out:
# {23}

# %%
s.add("aman")

# %%
s
# Out:
# {23, 'aman'}

# %%
s.add([213,43])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 s.add([213,43])
#
# TypeError: unhashable type: 'list'

# %%
l = [23,23,23,23,23,32,4,34,433,34,43,[45,54],34,54,554,]

# %%
set(l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 set(l)
#
# TypeError: unhashable type: 'list'

# %%
s
# Out:
# {23, 'aman'}

# %%
s.add(9867)

# %%
s
# Out:
# {23, 9867, 'aman'}

# %%
s.remove(23)

# %%
s
# Out:
# {9867, 'aman'}

# %%
s.pop()
# Out:
# 9867

# %%
s
# Out:
# {'aman'}

# %%
9876 in s
# Out:
# False

# %%
s.clear()

# %%
s
# Out:
# set()

# %%
s.copy()
# Out:
# set()

# %%
s
# Out:
# set()

# %%
s = set(l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 s = set(l)
#
# TypeError: unhashable type: 'list'

# %%
s
# Out:
# set()

# %%
s.add("8765|")

# %%
s.add(8765)

# %%
s.add(76)

# %%
s
# Out:
# {76, 8765, '8765|'}

# %%
l = [123,23,232,23,2,23]

# %%
s1 = set(l)

# %%
s + s1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 s + s1
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
s*4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 s*4
#
# TypeError: unsupported operand type(s) for *: 'set' and 'int'

# %%
s
# Out:
# {76, 8765, '8765|'}

# %%
list()
# Out:
# []

# %%
l4 = list(s)

# %%
l4
# Out:
# ['8765|', 8765, 76]

# %%
l4.append("aha")

# %%
l4
# Out:
# ['8765|', 8765, 76, 'aha']

# %%
set(l4)
# Out:
# {76, 8765, '8765|', 'aha'}

# %%
s[0] = "s"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 s[0] = "s"
#
# TypeError: 'set' object does not support item assignment

# %%
s = set()

# %%
l = [2,3,4,5,66,6,6,66,66,66,]

# %%
s = set(l)

# %%
s
# Out:
# {2, 3, 4, 5, 6, 66}

# %%
tuple(s)
# Out:
# (66, 2, 3, 4, 5, 6)

# %%
s = {}

# %%
type(s)
# Out:
# dict

# %%
s = {2,3}

# %%
type(s)
# Out:
# set

# %% [markdown]
# #### Dictonary :-Exist in Key value pair .
# Key always be unique Value wiil be same but key will not be same

# %%
x = {}

# %%
type(x)
# Out:
# dict

# %%
x1 = {"hello"}

# %%
x1
# Out:
# {'hello'}

# %%
x2 = {"name": "Aman", "Address":"Jagdish", True: 9090, "value": [23,4,43,33,3]}

# %%
x2
# Out:
# {'name': 'Aman', 'Address': 'Jagdish', True: 9090, 'value': [23, 4, 43, 33, 3]}

# %%
x3 = {"Temple":{"Hamnuman": "ramgarh", "Sanker": "Ranchi"},"name": "Aman", "Address":"Jagdish", True: 9090, "value": [23,4,43,33,3]}

# %%
x3
# Out:
# {'Temple': {'Hamnuman': 'ramgarh', 'Sanker': 'Ranchi'},
#  'name': 'Aman',
#  'Address': 'Jagdish',
#  True: 9090,
#  'value': [23, 4, 43, 33, 3]}

# %%
x2 = {(93,4,5,5): "Aman", "Address":"Jagdish", True: 9090, "value": [23,4,43,33,3]}

# %%
x2
# Out:
# {(93, 4, 5, 5): 'Aman',
#  'Address': 'Jagdish',
#  True: 9090,
#  'value': [23, 4, 43, 33, 3]}

# %%
x2["Address"]
# Out:
# 'Jagdish'

# %%
x2["value"]
# Out:
# [23, 4, 43, 33, 3]

# %%
x2["value"][3]
# Out:
# 33

# %%
x3["Temple"]
# Out:
# {'Hamnuman': 'ramgarh', 'Sanker': 'Ranchi'}

# %%
type(x3["Temple"])
# Out:
# dict

# %%
x3 = {5: "war","k4": [43,343,53]}

# %%
x3
# Out:
# {5: 'war', 'k4': [43, 343, 53]}

# %%
x1 + x3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 x1 + x3
#
# TypeError: unsupported operand type(s) for +: 'set' and 'dict'

# %%
x3 * 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 x3 * 3
#
# TypeError: unsupported operand type(s) for *: 'dict' and 'int'

# %%
x3
# Out:
# {5: 'war', 'k4': [43, 343, 53]}

# %%
x3["k4"] = "aman"

# %%
x3
# Out:
# {5: 'war', 'k4': 'aman'}

# %%
x3["k4"] = 43

# %%
x3
# Out:
# {5: 'war', 'k4': 43}

# %%
x3["k4"]  = x3["k4"] -10

# %%
x3
# Out:
# {5: 'war', 'k4': 33}

# %%
x3["k4"]  -= 10

# %%
x3
# Out:
# {5: 'war', 'k4': 23}

# %%
x3.keys()
# Out:
# dict_keys([5, 'k4'])

# %%
"k4" in x3.keys()
# Out:
# True

# %%
for i in x3:
    print(i)
# Out:
# 5
# k4

# %%
for i in x3.keys():
    print(x3[i])
# Out:
# war
# 23

# %%
x3
# Out:
# {5: 'war', 'k4': 23}

# %%
"k4" in x3
# Out:
# True

# %%
x2
# Out:
# {(93, 4, 5, 5): 'Aman',
#  'Address': 'Jagdish',
#  True: 9090,
#  'value': [23, 4, 43, 33, 3]}

# %%
x2.keys()
# Out:
# dict_keys([(93, 4, 5, 5), 'Address', True, 'value'])

# %%
for i in x2.keys():
    print(x2[i])
# Out:
# Aman
# Jagdish
# 9090
# [23, 4, 43, 33, 3]

# %%
for i in x2.keys():
    print(type(x2[i]))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'list'>

# %%
x2
# Out:
# {(93, 4, 5, 5): 'Aman',
#  'Address': 'Jagdish',
#  True: 9090,
#  'value': [23, 4, 43, 33, 3]}

# %%
x2.items()
# Out:
# dict_items([((93, 4, 5, 5), 'Aman'), ('Address', 'Jagdish'), (True, 9090), ('value', [23, 4, 43, 33, 3])])

# %%
for i in x2.items():
    print(i)
# Out:
# ((93, 4, 5, 5), 'Aman')
# ('Address', 'Jagdish')
# (True, 9090)
# ('value', [23, 4, 43, 33, 3])

# %%
for i in x2.items():
    print(i[0])
# Out:
# (93, 4, 5, 5)
# Address
# True
# value

# %%
for i in x2.items():
    print(i[1])
# Out:
# Aman
# Jagdish
# 9090
# [23, 4, 43, 33, 3]

# %%
x5 = {(23,32,32): "hgfdtydus"}

# %%
x5[(23,32,32)]
# Out:
# 'hgfdtydus'

# %%
x2
# Out:
# {(93, 4, 5, 5): 'Aman',
#  'Address': 'Jagdish',
#  True: 9090,
#  'value': [23, 4, 43, 33, 3]}

# %%
len(x2)
# Out:
# 4

# %%
e = {56: {45,76,89}}

# %%
type(e)
# Out:
# dict

# %%
e
# Out:
# {56: {45, 76, 89}}

# %%
e[56]
# Out:
# {45, 76, 89}

# %%
type(e[56])
# Out:
# set

# %%
e[56].remove(45)

# %%
e
# Out:
# {56: {76, 89}}

# %%
type(e[56])
# Out:
# set

# %%
list(e[56])[-1]
# Out:
# 76

# %%
e
# Out:
# {56: {76, 89}}

# %%
a = input("enter a paragraph")
# Out:
# enter a paragraph India, officially the Republic of India,[j][20] is a country in South Asia. It is the seventh-largest country by area; the most populous country since 2023;[21] and, since its independence in 1947, the world's most populous democracy.[22][23][24] Bounded by the Indian Ocean on the south, the Arabian Sea on the southwest, and the Bay of Bengal on the southeast, it shares land borders with Pakistan to the west;[k] China, Nepal, and Bhutan to the north; and Bangladesh and Myanmar to the east. In the Indian Ocean, India is near Sri Lanka and the Maldives; its Andaman and Nicobar Islands share a maritime border with Myanmar, Thailand, and Indonesia.  Modern humans arrived on the Indian subcontinent from Africa no later than 55,000 years ago.[26][27][28] Their long occupation, predominantly in isolation as hunter-gatherers, has made the region highly diverse.[29] Settled life emerged on the subcontinent in the western margins of the Indus river basin 9,000 years ago, evol
# ...

# %%
a
# Out:
# "India, officially the Republic of India,[j][20] is a country in South Asia. It is the seventh-largest country by area; the most populous country since 2023;[21] and, since its independence in 1947, the world's most populous democracy.[22][23][24] Bounded by the Indian Ocean on the south, the Arabian Sea on the southwest, and the Bay of Bengal on the southeast, it shares land borders with Pakistan to the west;[k] China, Nepal, and Bhutan to the north; and Bangladesh and Myanmar to the east. In the Indian Ocean, India is near Sri Lanka and the Maldives; its Andaman and Nicobar Islands share a maritime border with Myanmar, Thailand, and Indonesia.  Modern humans arrived on the Indian subcontinent from Africa no later than 55,000 years ago.[26][27][28] Their long occupation, predominantly in isolation as hunter-gatherers, has made the region highly diverse.[29] Settled life emerged on the subcontinent in the western margins of the Indus river basin 9,000 years ago, evolving gradually in
# ...

# %%
a = list(a)

# %%
print(a, end = "")
# Out:
# ['I', 'n', 'd', 'i', 'a', ',', ' ', 'o', 'f', 'f', 'i', 'c', 'i', 'a', 'l', 'l', 'y', ' ', 't', 'h', 'e', ' ', 'R', 'e', 'p', 'u', 'b', 'l', 'i', 'c', ' ', 'o', 'f', ' ', 'I', 'n', 'd', 'i', 'a', ',', '[', 'j', ']', '[', '2', '0', ']', ' ', 'i', 's', ' ', 'a', ' ', 'c', 'o', 'u', 'n', 't', 'r', 'y', ' ', 'i', 'n', ' ', 'S', 'o', 'u', 't', 'h', ' ', 'A', 's', 'i', 'a', '.', ' ', 'I', 't', ' ', 'i', 's', ' ', 't', 'h', 'e', ' ', 's', 'e', 'v', 'e', 'n', 't', 'h', '-', 'l', 'a', 'r', 'g', 'e', 's', 't', ' ', 'c', 'o', 'u', 'n', 't', 'r', 'y', ' ', 'b', 'y', ' ', 'a', 'r', 'e', 'a', ';', ' ', 't', 'h', 'e', ' ', 'm', 'o', 's', 't', ' ', 'p', 'o', 'p', 'u', 'l', 'o', 'u', 's', ' ', 'c', 'o', 'u', 'n', 't', 'r', 'y', ' ', 's', 'i', 'n', 'c', 'e', ' ', '2', '0', '2', '3', ';', '[', '2', '1', ']', ' ', 'a', 'n', 'd', ',', ' ', 's', 'i', 'n', 'c', 'e', ' ', 'i', 't', 's', ' ', 'i', 'n', 'd', 'e', 'p', 'e', 'n', 'd', 'e', 'n', 'c', 'e', ' ', 'i', 'n', ' ', '1', '9', '4', '7', ',', ' ', 't', 'h
# ...

# %%
a = set(a)

# %%
print(a, end = "")
# Out:
# {'W', 'Z', 'm', '5', 'b', 'C', ']', 'G', '8', 'o', '1', ',', "'", '6', 'E', 'j', ';', 'r', 'U', 'k', 'B', 'M', 'x', '3', 'h', 'P', '7', 'I', 'N', ' ', 'S', 'A', 'V', '%', 'T', 'H', 'a', 'D', 'e', 'u', 's', 'v', 'J', 'g', 'y', '9', 'c', 'O', '0', '4', '2', '-', 'w', 'L', 'R', '$', 'f', 'i', 'd', 'p', 't', '[', 'q', '.', 'l', 'n'}

# %%
a = list(a)

# %%
a
# Out:
# ['W',
#  'Z',
#  'm',
#  '5',
#  'b',
#  'C',
#  ']',
#  'G',
#  '8',
#  'o',
#  '1',
#  ',',
#  "'",
#  '6',
#  'E',
#  'j',
#  ';',
#  'r',
#  'U',
#  'k',
#  'B',
#  'M',
#  'x',
#  '3',
#  'h',
#  'P',
#  '7',
#  'I',
#  'N',
#  ' ',
#  'S',
#  'A',
#  'V',
#  '%',
#  'T',
#  'H',
#  'a',
#  'D',
#  'e',
#  'u',
#  's',
#  'v',
#  'J',
#  'g',
#  'y',
#  '9',
#  'c',
#  'O',
#  '0',
#  '4',
#  '2',
#  '-',
#  'w',
#  'L',
#  'R',
#  '$',
#  'f',
#  'i',
#  'd',
#  'p',
#  't',
#  '[',
#  'q',
#  '.',
#  'l',
#  'n']

# %%
data = input("Enter the paragraph -->>")
data_list = data.split(" ")
# Out:
# Enter the paragraph -->> This is the list of countries and other inhabited territories of the world by estimated total population. It is based on estimates published by the United Nations in the 2024 revision of World Population Prospects. It presents population estimates from 1950 to the present.

# %%
data_list
# Out:
# ['This',
#  'is',
#  'the',
#  'list',
#  'of',
#  'countries',
#  'and',
#  'other',
#  'inhabited',
#  'territories',
#  'of',
#  'the',
#  'world',
#  'by',
#  'estimated',
#  'total',
#  'population.',
#  'It',
#  'is',
#  'based',
#  'on',
#  'estimates',
#  'published',
#  'by',
#  'the',
#  'United',
#  'Nations',
#  'in',
#  'the',
#  '2024',
#  'revision',
#  'of',
#  'World',
#  'Population',
#  'Prospects.',
#  'It',
#  'presents',
#  'population',
#  'estimates',
#  'from',
#  '1950',
#  'to',
#  'the',
#  'present.']

# %%
no_duplicate = set(data_list)

# %%
no_duplicate
# Out:
# {'1950',
#  '2024',
#  'It',
#  'Nations',
#  'Population',
#  'Prospects.',
#  'This',
#  'United',
#  'World',
#  'and',
#  'based',
#  'by',
#  'countries',
#  'estimated',
#  'estimates',
#  'from',
#  'in',
#  'inhabited',
#  'is',
#  'list',
#  'of',
#  'on',
#  'other',
#  'population',
#  'population.',
#  'present.',
#  'presents',
#  'published',
#  'revision',
#  'territories',
#  'the',
#  'to',
#  'total',
#  'world'}

# %%
my_dict = {}
for i in no_duplicate:
    my_dict[i] = "aman"

# %%
my_dict
# Out:
# {'total': 'aman',
#  'population': 'aman',
#  'Prospects.': 'aman',
#  'the': 'aman',
#  '2024': 'aman',
#  'territories': 'aman',
#  'in': 'aman',
#  'of': 'aman',
#  'It': 'aman',
#  'present.': 'aman',
#  'population.': 'aman',
#  'inhabited': 'aman',
#  'based': 'aman',
#  'by': 'aman',
#  'to': 'aman',
#  'on': 'aman',
#  'presents': 'aman',
#  'Population': 'aman',
#  'estimates': 'aman',
#  'published': 'aman',
#  'This': 'aman',
#  'Nations': 'aman',
#  'from': 'aman',
#  'other': 'aman',
#  'world': 'aman',
#  'and': 'aman',
#  'estimated': 'aman',
#  '1950': 'aman',
#  'United': 'aman',
#  'is': 'aman',
#  'list': 'aman',
#  'revision': 'aman',
#  'countries': 'aman',
#  'World': 'aman'}

# %%
tup_list = []
for i in my_dict.keys():
    tup_list.append(my_dict[i])

# %%
tuple(tup_list)
# Out:
# ('aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman')

# %%
list_key = []
for i in my_dict.keys():
    list_key.append(i)

# %%
list_key
# Out:
# ['total',
#  'population',
#  'Prospects.',
#  'the',
#  '2024',
#  'territories',
#  'in',
#  'of',
#  'It',
#  'present.',
#  'population.',
#  'inhabited',
#  'based',
#  'by',
#  'to',
#  'on',
#  'presents',
#  'Population',
#  'estimates',
#  'published',
#  'This',
#  'Nations',
#  'from',
#  'other',
#  'world',
#  'and',
#  'estimated',
#  '1950',
#  'United',
#  'is',
#  'list',
#  'revision',
#  'countries',
#  'World']

# %%
paragraph = input("enter the parag")
list1 = paragraph.split(" ")
s1 = set(list1)
dict1 = dict.fromkeys(s1, "aman")
t1 = tuple(dict1.keys())
l2 = list(dict1.values())
# Out:
# enter the parag This is the list of countries and other inhabited territories of the world by estimated total population. It is based on estimates published by the United Nations in the 2024 revision of World Population Prospects. It presents population estimates from 1950 to the present.

# %%
t1
# Out:
# ('total',
#  'population',
#  'Prospects.',
#  'the',
#  '2024',
#  'territories',
#  'in',
#  'of',
#  'It',
#  'present.',
#  'population.',
#  'inhabited',
#  'based',
#  'by',
#  'to',
#  'on',
#  'presents',
#  'Population',
#  'estimates',
#  'published',
#  'This',
#  'Nations',
#  'from',
#  'other',
#  'world',
#  'and',
#  'estimated',
#  '1950',
#  'United',
#  'is',
#  'list',
#  'revision',
#  'countries',
#  'World')

# %%
l2
# Out:
# ['aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman',
#  'aman']

# %%
d = {"company": "ineuron", "course": "Full Stack science", "year": 2021}

# %%
for i in d:
    print("print a key :", i, ", value wise : ", d[i])
# Out:
# print a key : company , value wise :  ineuron
# print a key : course , value wise :  Full Stack science
# print a key : year , value wise :  2021

# %%
"course" in d
# Out:
# True

# %%
if i in d:
    if i == "year":
        if d[i] > 2021:
            print("year is fine")
        else:
            d[i] = 2022
# Out:
# year is fine

# %%
d
# Out:
# {'company': 'ineuron', 'course': 'Full Stack science', 'year': 2022}

# %%
for i in d:
    if i == "course":
        if len(i) > 4:
            print(d[i].split())
# Out:
# ['Full', 'Stack', 'science']

# %%
my_dict = {}
for i in range(10):
    my_dict[i] = i*i

# %%
my_dict
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %%
{i : i*i for i in range(10)}
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}
