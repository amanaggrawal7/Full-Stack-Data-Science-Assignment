# %%
import math

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt

# %%
sqrt(5)
# Out:
# 2.23606797749979

# %%
sqrt(19)
# Out:
# 4.358898943540674

# %%
from math import sqrt, pi

# %%
pi
# Out:
# 3.141592653589793

# %%
from math import *

# %%
sqrt(28976)
# Out:
# 170.2233826476257

# %%
math.pi
# Out:
# 3.141592653589793

# %%
import math

# %%
math.sqrt(4)
# Out:
# 2.0

# %%
type(math.sqrt(4))
# Out:
# float

# %%
from math import sqrt,pi

# %%
sqrt(4)
# Out:
# 2.0

# %%
pi
# Out:
# 3.141592653589793

# %%
from math import *

# %%
sqrt(3)
# Out:
# 1.7320508075688772

# %%
sin(0)
# Out:
# 0.0

# %%
sin(30)
# Out:
# -0.9880316240928618

# %%
sin(90)
# Out:
# 0.8939966636005579

# %%
pi
# Out:
# 3.141592653589793

# %%
pwd
# Out:
# 'C:\\Users\\aman0'

# %%
import os

# %%
pwd
# Out:
# 'C:\\Users\\aman0'

# %%
import Test1
# Out:
# This ismy first ever module

# %%
import Test1

# %%
import Test1

# %%
Test1
# Out:
# <module 'Test1' from 'C:\\Users\\aman0\\Test1.py'>

# %%
import addition

# %%
addition.addition(2,3)
# Out:
# 5

# %%
import test5

# %%
import test5

# %%
import test5

# %%
import cal

# %%
cal.add(3,4)
# Out:
# 7

# %%
cal.mul(5,67)
# Out:
# 335

# %%
import Test6

# %%
Test6.get_course()
# Out:
# ['ml', 'dl', 'py', 'stats', 'cv']

# %%
from Test6 import get_course

# %%
Test6.msg()
# Out:
# 'This is a my class'

# %%
import Test6

# %%
Test6.msg()
# Out:
# 'This is a my class'

# %%
Test6.get_course()
# Out:
# ['ml', 'dl', 'py', 'stats', 'cv']

# %%
import Test7

# %%
Test7.data
# Out:
# {'name': 'AMAN', 'Course': ['BCA', 'dl', 'PY'], 'msg': 'This is my class'}

# %%
Test7.msg()
# Out:
# 'This is my class'

# %%
 Test7.get_course()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 Test7.get_course()
#
# File ~\Test7.py:8, in get_course()
#       7 def get_course():
# ----> 8     return data["course"]
#
# KeyError: 'course'

# %%
from Test6 import msg

# %%
Test6.msg()
# Out:
# 'This is a my class'

# %%
import os

# %%
os.mkdir("test")

# %%
os.mkdir("test1")

# %%
os.chdir("test1")

# %%
pwd
# Out:
# 'C:\\Users\\aman0\\test1'

# %%
os.mkdir("test")

# %%
os.chdir("test")

# %%
pwd
# Out:
# 'C:\\Users\\aman0\\test1\\test'
