# %%
#Tuples

# %%
t = ()

# %%
type(t)
# Out:
# tuple

# %%
l = []

# %%
type(l)
# Out:
# list

# %%
t1 = (364,45,"aman", True, 2.322)

# %%
t1
# Out:
# (364, 45, 'aman', True, 2.322)

# %%
type(t1)
# Out:
# tuple

# %%
t1
# Out:
# (364, 45, 'aman', True, 2.322)

# %%
t1[0]
# Out:
# 364

# %%
t1[3]
# Out:
# True

# %%
t1[0:4]
# Out:
# (364, 45, 'aman', True)

# %%
t1[::-1]
# Out:
# (2.322, True, 'aman', 45, 364)

# %%
t1
# Out:
# (364, 45, 'aman', True, 2.322)

# %%
t1[::-2]
# Out:
# (2.322, 'aman', 364)

# %%
t1.count("aman")
# Out:
# 1

# %%
t1.index("aman")
# Out:
# 2

# %%
l1 = ["aman", 1,2,3]

# %%
l1
# Out:
# ['aman', 1, 2, 3]

# %%
l1[0]
# Out:
# 'aman'

# %%
l1[0] = "anshu"

# %%
l1
# Out:
# ['anshu', 1, 2, 3]

# %%
t1[0]
# Out:
# 364

# %%
t1[0] = "aman"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 t1[0] = "aman"
#
# TypeError: 'tuple' object does not support item assignment

# %%
t2 = (45,43,43)

# %%
t1 + t2
# Out:
# (364, 45, 'aman', True, 2.322, 45, 43, 43)

# %%
t1 = (938,86)

# %%
t2 = ("aman", "kumar")

# %%
t1 + t2
# Out:
# (938, 86, 'aman', 'kumar')

# %%
t1*2
# Out:
# (938, 86, 938, 86)

# %%
t1
# Out:
# (938, 86)

# %%
98 in t1
# Out:
# False

# %%
86 in t1
# Out:
# True

# %%
t1
# Out:
# (938, 86)

# %%
max(t1)
# Out:
# 938

# %%
t2 = ("aman", 98765)

# %%
max(t2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 max(t2)
#
# TypeError: '>' not supported between instances of 'int' and 'str'

# %%
max(t1)
# Out:
# 938

# %%
t1.count(98)
# Out:
# 0

# %%
l1
# Out:
# ['anshu', 1, 2, 3]

# %%
t1.index(3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 t1.index(3)
#
# ValueError: tuple.index(x): x not in tuple

# %%
t1.index("a")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 t1.index("a")
#
# ValueError: tuple.index(x): x not in tuple

# %%
t1 = (2,3,5,6,7,7)

# %%
t1.index(7)
# Out:
# 4

# %%
min(t1)
# Out:
# 2

# %%
t2 = (2,2,2,2,2,2)

# %%
t1 + t2
# Out:
# (2, 3, 5, 6, 7, 7, 2, 2, 2, 2, 2, 2)

# %%
t5 = 56

# %%
l6 = list(t1+t2)

# %%
l6
# Out:
# [2, 3, 5, 6, 7, 7, 2, 2, 2, 2, 2, 2]

# %%
l6.insert(3,62)

# %%
tuple(l6)
# Out:
# (2, 3, 5, 62, 6, 7, 7, 2, 2, 2, 2, 2, 2)

# %%
l6
# Out:
# [2, 3, 5, 62, 6, 7, 7, 2, 2, 2, 2, 2, 2]

# %%
t = ((3,2,3,44),(267,276,"aman"), (6523,9),3, 44,[32,43,43])

# %%
t
# Out:
# ((3, 2, 3, 44), (267, 276, 'aman'), (6523, 9), 3, 44, [32, 43, 43])

# %%
t[5]
# Out:
# [32, 43, 43]

# %%
t[::-1]
# Out:
# ([32, 43, 43], 44, 3, (6523, 9), (267, 276, 'aman'), (3, 2, 3, 44))

# %%
t[5]
# Out:
# [32, 43, 43]

# %%
type(t[5])
# Out:
# list

# %%
t[5][1]
# Out:
# 43

# %%
t[5][0:2]
# Out:
# [32, 43]

# %%
for i in t:
    print(i)
# Out:
# (3, 2, 3, 44)
# (267, 276, 'aman')
# (6523, 9)
# 3
# 44
# [32, 43, 43]

# %%
for i in t:
    if type(i) == tuple:
        print(i[1])
# Out:
# 2
# 276
# 9

# %%
t1
# Out:
# (2, 3, 5, 6, 7, 7)

# %%
t2
# Out:
# (2, 2, 2, 2, 2, 2)

# %%
if len(t1) == len(t2):
    print("its same")
else:
    print("not same")
# Out:
# its same

# %%
t = (23,234,4,3,3343,43,43,"Trye", "ajhgsah", "t")

# %%
i = input("take a user input")
if i in t :
    print("yes your name is availabe")
else:
    print("youor name is not availabe")
# Out:
# take a user input aman
# youor name is not availabe

# %%
l1
# Out:
# ['anshu', 1, 2, 3]

# %%
del(l1)

# %%
l1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 l1
#
# NameError: name 'l1' is not defined

# %%
del(t1)

# %%
t1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 t1
#
# NameError: name 't1' is not defined

# %%
del(t2)

# %%
l
# Out:
# []

# %%
l = [637,32,43,4,3,4]

# %%
t = (2123,3,23,21)

# %%
t
# Out:
# (2123, 3, 23, 21)
