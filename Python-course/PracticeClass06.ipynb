# %%
l = []

# %%
l.append("aman kumar")

# %%
l
# Out:
# ['aman kumar']

# %%
l.append("hello")

# %%
l
# Out:
# ['aman kumar', 'hello']

# %%
l.append(["Hello, how , are, you, my, name, is, Suhil "])

# %%
l
# Out:
# ['aman kumar', 'hello', ['Hello, how , are, you, my, name, is, Suhil ']]

# %%
l.append(65)

# %%
l
# Out:
# ['aman kumar', 'hello', ['Hello, how , are, you, my, name, is, Suhil '], 65]

# %%
l.insert(2,98)

# %%
l
# Out:
# ['aman kumar',
#  'hello',
#  98,
#  ['Hello, how , are, you, my, name, is, Suhil '],
#  65]

# %%
l.insert(4, 87654)

# %%
l
# Out:
# ['aman kumar',
#  'hello',
#  98,
#  ['Hello, how , are, you, my, name, is, Suhil '],
#  87654,
#  65]

# %%
l.insert(3, ["hello", "bollo"])

# %%
l
# Out:
# ['aman kumar',
#  'hello',
#  98,
#  ['hello', 'bollo'],
#  ['Hello, how , are, you, my, name, is, Suhil '],
#  87654,
#  65]

# %%
reversed(l)

# %%
l
# Out:
# ['aman kumar',
#  'hello',
#  98,
#  ['hello', 'bollo'],
#  ['Hello, how , are, you, my, name, is, Suhil '],
#  87654,
#  65]

# %%
l.reverse()

# %%
l
# Out:
# []

# %%
l.clear()

# %%
l
# Out:
# []

# %%
l
# Out:
# [65,
#  87654,
#  ['Hello, how , are, you, my, name, is, Suhil '],
#  ['hello', 'bollo'],
#  98,
#  'hello',
#  'aman kumar']

# %%
l.copy()
# Out:
# [65,
#  87654,
#  ['Hello, how , are, you, my, name, is, Suhil '],
#  ['hello', 'bollo'],
#  98,
#  'hello',
#  'aman kumar']

# %%
l
# Out:
# [65,
#  87654,
#  ['Hello, how , are, you, my, name, is, Suhil '],
#  ['hello', 'bollo'],
#  98,
#  'hello',
#  'aman kumar']

# %%
l.count(65)
# Out:
# 1

# %%
l.extend("aman")

# %%
l
# Out:
# [65,
#  87654,
#  ['Hello, how , are, you, my, name, is, Suhil '],
#  ['hello', 'bollo'],
#  98,
#  'hello',
#  'aman kumar',
#  'a',
#  'm',
#  'a',
#  'n']

# %%
len(l)
# Out:
# 11

# %%
l.pop(10)
# Out:
# 'n'

# %%
l
# Out:
# [65,
#  87654,
#  ['Hello, how , are, you, my, name, is, Suhil '],
#  ['hello', 'bollo'],
#  98,
#  'hello',
#  'aman kumar',
#  'a',
#  'm',
#  'a']

# %%
l.pop(8)
# Out:
# 'm'

# %%
l
# Out:
# [65,
#  87654,
#  ['Hello, how , are, you, my, name, is, Suhil '],
#  ['hello', 'bollo'],
#  98,
#  'hello',
#  'aman kumar',
#  'a',
#  'a']

# %%
l.count("a")
# Out:
# 2

# %%
l.index("hello")
# Out:
# 5

# %%
l.index("a")
# Out:
# 7

# %%
l.remove("a")

# %%
l
# Out:
# [65,
#  87654,
#  ['Hello, how , are, you, my, name, is, Suhil '],
#  ['hello', 'bollo'],
#  98,
#  'hello',
#  'aman kumar',
#  'a']

# %%
l.remove("hello")

# %%
l
# Out:
# [65,
#  87654,
#  ['Hello, how , are, you, my, name, is, Suhil '],
#  ['hello', 'bollo'],
#  98,
#  'aman kumar',
#  'a']

# %%
len(l)
# Out:
# 7

# %%
l.remove(65)

# %%
l
# Out:
# [87654,
#  ['Hello, how , are, you, my, name, is, Suhil '],
#  ['hello', 'bollo'],
#  98,
#  'aman kumar',
#  'a']

# %%
l.clear()

# %%
l
# Out:
# []

# %%
l.append("Hello")

# %%
l.insert(1, "My")

# %%
l
# Out:
# ['Hello', 'My']

# %%
l.sort()

# %%
l
# Out:
# ['Hello', 'My']

# %%
l.clear()

# %%
l = ["aman", "kumar", "aggrawal", "aggrawal", "one"]

# %%
l.sort()

# %%
l
# Out:
# ['aggrawal', 'aggrawal', 'aman', 'kumar', 'one']

# %%
l.reverse()

# %%
l
# Out:
# ['one', 'kumar', 'aman', 'aggrawal', 'aggrawal']

# %%
l.insert(3, ["aman", "kumar"])

# %%
l
# Out:
# ['one', 'kumar', 'aman', ['aman', 'kumar'], 'aggrawal', 'aggrawal']

# %%
l.reverse()

# %%
l
# Out:
# ['aggrawal', 'aggrawal', ['aman', 'kumar'], 'aman', 'kumar', 'one']

# %%
l.clear()

# %%
l
# Out:
# []

# %%
l =  [["aman",99,"kumar", "kumar"],[12,"b","b"],["c"],65]

# %%
l
# Out:
# [['aman', 99, 'kumar', 'kumar'], [12, 'b', 'b'], ['c'], 65]

# %%
for i in l:
    if type(i) == list:
        b = l.index(i)
        for j in i:
            if type(j) == str:
                #print("index of {} is {},{} ".format(i) )
                a = i.index(j)
                print("The index of {} is {},{}".format(j,b,a))
                i.remove(j)
                continue
# Out:
# The index of kumar is 0,1
# The index of b is 1,1
# The index of c is 2,0

# %%
l
# Out:
# [[99, 'kumar'], [12, 'b'], [], 65]

# %%
l =  [["aman",99,"kumar", "kumar"],[12,"b","b"],["c"],65]

# %%
for i in l:
    if type(i) == list:
        j = 0
        while j<len(i):
            if type(i[j]) == str:
                print("Index of string {} is: {} ".format(i[j], j))
            j = j+1

        j = 0
        while j<len(i):
            if type(i[j]) == str:
                print("The string in the nested list is {}".format(i[j]))
                i.remove(i[j])
                continue
            j = j+1
# Out:
# Index of string aman is: 0
# Index of string kumar is: 2
# Index of string kumar is: 3
# The string in the nested list is aman
# The string in the nested list is kumar
# The string in the nested list is kumar
# Index of string b is: 1
# Index of string b is: 2
# The string in the nested list is b
# The string in the nested list is b
# Index of string c is: 0
# The string in the nested list is c

# %%
l
# Out:
# [[99], [12], [], 65]

# %%
l =  [["aman",99,"kumar", "kumar"],[12,"b","b"],["c"],65]

# %%
for i in l:
    if type(i) == list:
        for j in range(len(i)):
            if type(i[j]) == str:
                print("the index of {} is {}".format(i[j],j))

        j = len(i)-1
        while(j>=0):
            if type(i[j]) == str:
                print(i)
                i.pop(j)
            j = j-1
# Out:
# the index of aman is 0
# the index of kumar is 2
# the index of kumar is 3
# ['aman', 99, 'kumar', 'kumar']
# ['aman', 99, 'kumar']
# ['aman', 99]
# the index of b is 1
# the index of b is 2
# [12, 'b', 'b']
# [12, 'b']
# the index of c is 0
# ['c']

# %%
l
# Out:
# [['aman', 99, 'kumar', 'kumar'], [12, 'b', 'b'], ['c'], 65]

# %%
for i in l:
    if type(i) == list:
        if len(i) >1:
        i.pop(1)
# Out:
#   Cell In[12], line 4
#     i.pop(1)
#     ^
# IndentationError: expected an indented block after 'if' statement on line 3
