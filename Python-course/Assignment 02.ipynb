# %% [markdown]
# Assignment 2

# %% [markdown]
# 1.Write a Python program to convert Kilometers to Miles ?

# %%
kilometers = float(input("Enter a km for convertion into miles"))
print("{} km is {} mile".format(kilometers, kilometers*0.621))
# Out:
# Enter a km for convertion into miles 1000
# 1000.0 km is 621.0 mile

# %%
kilometers = float(input("Enter a km for convertion into miles"))
print("Kilometers", kilometers)
print("Miles", kilometers* 0.621)
# Out:
# Enter a km for convertion into miles 1000
# Kilometers 1000.0
# Miles 621.0

# %% [markdown]
# 2.Write a Python program to convert Celsius to Farenheit ?

# %%
celsius = int(input("Enter a temperatue in celcius :"))
fareneit = (celsius*(9/5)) + 32
print("{}°C celcius is {}°f ferenite".format(celsius, fareneit))
# Out:
# Enter a temperatue in celcius : 100
# 100°C celcius is 212.0°f ferenite

# %% [markdown]
# 3.Write a Python program to display calender ?

# %%
import calender
def showCalender():
    year = int(input("Enter calender year"))
    print(calender.calender(year))
showCalender()

# %% [markdown]
# 4.Write a Python program to solve quadartic equation ?
