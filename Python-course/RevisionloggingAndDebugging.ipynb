# %%
import os

# %%
os.chdir("D: ")

# %%
os.chdir("Lecture notes Ineuron")

# %%
os.mkdir("LoggingAndDebugging")

# %%
os.chdir("LoggingAndDebugging/")

# %%
import logging as lg

# %%
lg.basicConfig(filename = "Test.log", level = lg.INFO, format = '%(asctime)s %(message)s' )

# %%
lg.info("Hello Krish, I have a question about related to logging and debugging, I can ask or not")

# %%
f = open("Test.log", "r")

# %%
f.read()
# Out:
# 'INFO:root:Hello Krish, I have a question about related to logging and debugging, I can ask or not\n'

# %%
lg.error("Hey, There is an error related to something")

# %%
lg.warning("This is warning")

# %%
lg.debug("Debug all the fundamental right")

# %%
f.read()
# Out:
# 'ERROR:root:Hey, There is an error related to something\nWARNING:root:This is warning\n'

# %%
f.close()

# %%
f = open("Test.log","r+")

# %%
f.read()
# Out:
# 'INFO:root:Hello Krish, I have a question about related to logging and debugging, I can ask or not\nERROR:root:Hey, There is an error related to something\nWARNING:root:This is warning\n'

# %%
def test(a,b):
    try:
        lg.info(str(a) + str(b))
        div = a/b
        return div
    except Exception as e:
        print("You can check you log for more into if your code will fall")
        lg.error("error was occured")
        lg.exception(str(e))

# %%
test(4,0)
# Out:
# You can check you log for more into if your code will fall

# %%
import logging as lg
lg.basicConfig(filename = "Test1.log", level = lg.INFO)
def Test1(a,b):
    lg.info("This is start fuction")
    return a+ b

# %%
Test1(2,3)
# Out:
# 5

# %%
os.listdir()
# Out:
# ['Test.log', 'Test1.log']

# %%
import os
os.chdir("D:/Python Programming/Lecture notes Ineuron/LoggingAndDebugging")

# %%
os.listdir()
# Out:
# ['Test.log', 'Test1.log']

# %%
import logging as lg
lg.basicConfig(filename = "Test3.log")

# %%
os.listdir()
# Out:
# ['Test.log', 'Test1.log', 'Test3.log']

# %%
import logging as lg
lg.basicConfig(filename = "Test3.log", force = True)
lg.debug("This is for debugging")
lg.info("This is for info")
lg.warning("this is warning log")
lg.error("this is my error log")
lg.exception("This is my exception log")
lg.critical("this is my criticallogging")

# %% [markdown]
# 1. Create a logger in your code
# 2. create one function which can take any number of input as an argument and it will bw able to return sum of it
# 3. capture user input in log
# 4. give user instruction in log file
# 5. read a log file from python code and show all login in console

# %%
import os
os.chdir("D:/Python Programming/Lecture notes Ineuron/LoggingAndDebugging")

# %%
import logging as lg
lg.basicConfig(filename = "Test4.log", level = lg.INFO)
def sum(*args):
    result = 0
    for i in args:
        lg.info(str(i))
        result = result+i
        lg.info(f"The sum of number is{result}")
    return result

sum(2,3,4,56,7,7)
# Out:
# 79

# %%
os.listdir()
# Out:
# ['Test.log', 'Test1.log', 'Test3.log', 'Test4.log']

# %%
f = open("Test4.log","r")

# %%
f.read()
# Out:
# 'INFO:root:2\nINFO:root:The sum of number is2\nINFO:root:3\nINFO:root:The sum of number is5\nINFO:root:4\nINFO:root:The sum of number is9\nINFO:root:56\nINFO:root:The sum of number is65\nINFO:root:7\nINFO:root:The sum of number is72\nINFO:root:7\nINFO:root:The sum of number is79\n'

# %%
import os
os.chdir("D:/Python Programming/Lecture notes Ineuron/LoggingAndDebugging")

# %%
import logging
logging.basicConfig(filename = 'app3.log' ,level = logging.DEBUG, format = '%(asctime)s %(name)s %(levelname)s %(message)s' , filemode='w')
console_log = logging.StreamHandler() # Print a logging information in your console
console_log.setLevel(logging.INFO)
format = '%(asctime)s %(name)s %(levelname)s %(message)s'
console_log.setFormatter(format)
logging.getLogger('').addHandler(console_log)
logging.info("This is my first test code for log")

logger1 = logging.getLogger('user1')
logger2 = logging.getLogger('user2')
logger3 = logging.getLogger('user3')
logger4 = logging.getLogger('user4')

logger1.info("This is info for logger one")
logger2.debug("This is debug for logger two")
logger2.info("This is info for logger 2")
logger3.info("This is info for logger 3")
logger4.error("This is error for logger 4")
# Out:
# %(asctime)s %(name)s %(levelname)s %(message)s
# %(asctime)s %(name)s %(levelname)s %(message)s
# %(asctime)s %(name)s %(levelname)s %(message)s
# %(asctime)s %(name)s %(levelname)s %(message)s
# %(asctime)s %(name)s %(levelname)s %(message)s

# %%
import logging
logging.basicConfig(filename = 'app2.log', level = logging.DEBUG, format = '%(name)s - %(asctime)s - %(levelname)s - %(message)s')

console_log = logging.StreamHandler()
console_log.setLevel(logging.DEBUG)
format = logging.Formatter('%(name)s - %(asctime)s - %(levelname)s - %(message)s')
console_log.setFormatter(format)

logging.getLogger('').addHandler(console_log)
logging.info('main log')
logger1 = logging.getLogger('user1')
logger2 = logging.getLogger('user2')
logger1.info('this is from user 1 info')
logger2.debug('This is from user2 debug')
# Out:
# root - 2026-01-17 15:29:21,115 - INFO - main log
# root - 2026-01-17 15:29:21,115 - INFO - main log
# root - 2026-01-17 15:29:21,115 - INFO - main log
# user1 - 2026-01-17 15:29:21,119 - INFO - this is from user 1 info
# user1 - 2026-01-17 15:29:21,119 - INFO - this is from user 1 info
# user1 - 2026-01-17 15:29:21,119 - INFO - this is from user 1 info
# user2 - 2026-01-17 15:29:21,122 - DEBUG - This is from user2 debug
# user2 - 2026-01-17 15:29:21,122 - DEBUG - This is from user2 debug
# user2 - 2026-01-17 15:29:21,122 - DEBUG - This is from user2 debug

# %%
pwd
# Out:
# 'D:\\Python Programming\\Lecture notes Ineuron\\LoggingAndDebugging'

# %%
def testdebug():
    ipdb.set_trace()
    l = []
    for i in range(10):
        for j in range(5):
            l.append(i)
            if i == 4:
                continue
            print("We have appended data in list")
    return l

# %%
testdebug()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 testdebug()
#
# Cell In[8], line 2, in testdebug()
#       1 def testdebug():
# ----> 2     ipdb.set_trace()
#       3     l = []
#       4     for i in range(10):
#
# NameError: name 'ipdb' is not defined
