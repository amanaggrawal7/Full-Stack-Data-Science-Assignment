# %%
f = open("test.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 f = open("test.txt")
#
# File D:\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.txt'

# %% [markdown]
# #### if file is not avialable then we create a file by using code
# #### w - open for writing

# %%
f = open("test.txt", "w")

# %%
f.write("amnajhbhwe")
# Out:
# 10

# %%
f.close()

# %%
f = open("test.txt")

# %%
f.read()
# Out:
# 'amnajhbhwe'

# %%
f.read()
# Out:
# '\nweywdef\nf\nerferf\ner\nferferf\nerf\ne\n'

# %%
f.read()
# Out:
# ''

# %%
f.close()

# %%
f = open("test.txt")

# %%
f.read()
# Out:
# 'amnajhbhwe\nweywdef\nf\nerferf\ner\nferferf\nerf\ne\n'

# %%
f.seek(10)
# Out:
# 10

# %%
f.read()
# Out:
# '\nweywdef\nf\nerferf\ner\nferferf\nerf\ne\n'

# %%
f.seek(2)
# Out:
# 2

# %%
f.read()
# Out:
# 'najhbhwe\nweywdef\nf\nerferf\ner\nferferf\nerf\ne\n'

# %%
f = open("test.txt","r")

# %%
f.write("aman")
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 f.write("aman")
#
# UnsupportedOperation: not writable

# %%
f.read()
# Out:
# 'amnajhbhwe\nweywdef\nf\nerferf\ner\nferferf\nerf\ne\n'

# %%
f.seek(1)
# Out:
# 1

# %%
f.read()
# Out:
# 'mnajhbhwe\nweywdef\nf\nerferf\ner\nferferf\nerf\ne\n'

# %%
f.read(25) # read 25 character for the where your cursor
# Out:
# ''

# %%
f.seek(1)
# Out:
# 1

# %%
f.read(25)
# Out:
# 'mnajhbhwe\nweywdef\nf\nerfer'

# %%
f.close()

# %%
f.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 f.read()
#
# ValueError: I/O operation on closed file.

# %%
f = open("test.txt","w")

# %%
f.write("hsxbw weh ufeiurh fheriferf ef eruhfui efhe")
# Out:
# 43

# %%
f.read()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 f.read()
#
# UnsupportedOperation: not readable

# %%
f.close()

# %%
f = open("test.txt", "a")

# %%
f.write("Hello how are yiu")
# Out:
# 17

# %%
f.write("ajbvggu whuhwk wdwe yudyuwgud yw")
# Out:
# 32

# %%
f.close()

# %%
f.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 f.read()
#
# ValueError: I/O operation on closed file.

# %%
f = open("test1.txt", "wb")

# %%
f.write("bhdwguy gweuygduwegkd weyuew")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 f.write("bhdwguy gweuygduwegkd weyuew")
#
# TypeError: a bytes-like object is required, not 'str'

# %%
f.write(b"bhdwguy gweuygduwegkd weyuew")# b is notation of binary
# Out:
# 28

# %%
f.close()

# %%
f = open("test1.txt","rb")

# %%
f.read()
# Out:
# b'bhdwguy gweuygduwegkd weyuew'

# %%
f.seek(2)
# Out:
# 2

# %%
f.read(1)
# Out:
# b'd'

# %%
f.seek(-3,2)# third byte before the end
# Out:
# 25

# %%
f.seek(-4,2)
# Out:
# 24

# %%
f = open("test2.txt", "w")

# %%
f.write("kndxwj jc hehce ifueruvgcu ygceyu gcweg licuowi")
# Out:
# 47

# %%
f.close()

# %%
f = open("test2.txt",'r')

# %%
f.read()
# Out:
# 'kndxwj jc hehce ifueruvgcu ygceyu gcweg licuowi'

# %%
f.read()
# Out:
# ''

# %%
f.read()
# Out:
# '\nd\ns\nfrefref\nefr\nef\nre\nfrf\nrf\nrfr3wfg3rg2g\nwffvfe\n fref f3rf3r\n fr3\n f3rf\n\n fr f \n3rffrc'

# %%
f.seek(0)
# Out:
# 0

# %%
f.readline()
# Out:
# 'kndxwj jc hehce ifueruvgcu ygceyu gcweg licuowi\n'

# %%
f.readline()
# Out:
# 'd\n'

# %%
f.readline(9)
# Out:
# 'frefref\n'

# %%
f.seek(0)
# Out:
# 0

# %%
f.readline(2)
# Out:
# 'kn'

# %%
f.readline(10)
# Out:
# 'dxwj jc he'

# %%
f.close()

# %%
f = open("test2.txt", "r")

# %%
for i in f:
    print(i, end = " ")
# Out:
# kndxwj jc hehce ifueruvgcu ygceyu gcweg licuowi
#  d
#  s
#  frefref
#  efr
#  ef
#  re
#  frf
#  rf
#  rfr3wfg3rg2g
#  wffvfe
#   fref f3rf3r
#   fr3
#   f3rf
#
#   fr f
#  3rffrc

# %%
f.close()

# %%
f = open("test2.txt", "r+")

# %%
list(f)
# Out:
# ['kndxwj jc hehce ifueruvgcu ygceyu gcweg licuowi\n',
#  'd\n',
#  's\n',
#  'frefref\n',
#  'efr\n',
#  'ef\n',
#  're\n',
#  'frf\n',
#  'rf\n',
#  'rfr3wfg3rg2g\n',
#  'wffvfe\n',
#  ' fref f3rf3r\n',
#  ' fr3\n',
#  ' f3rf\n',
#  '\n',
#  ' fr f \n',
#  '3rffrc']

# %%
f.write("aman aknjkn s diwe hwehdhd o2")
# Out:
# 29

# %%
f.close()

# %%
f = open("test2.txt", "r+")

# %%
f.writelines("dhwgdwed wydwyeudgwydwud w w wedweyugu")

# %%
f.close()

# %%
f.seek(345)
# Out:
# 345

# %%
f.close()

# %%
f = open("test2.txt", "r+")

# %%
f.fileno()
# Out:
# 3

# %%
# %%writefile test5.txt
# my name is aman
# Out:
# Writing test5.txt

# %%
import os

# %%
pwd() # Present working directory of notebook
# Out:
# 'C:\\Users\\aman0\\File2026'

# %%
os.getcwd() # Current working directory
# Out:
# 'C:\\Users\\aman0\\File2026'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'test.txt',
#  'test1.txt',
#  'test2.txt',
#  'test5.txt',
#  'text.txt',
#  'Untitled.ipynb']

# %%
os.listdir("D:\\Download 2\\")
# Out:
# ['0944XXXXXXXXX762611-03-2022.csv',
#  '0944XXXXXXXXX762611-03-2022.pdf',
#  '0944XXXXXXXXX762611-03-2022.txt',
#  '0944XXXXXXXXX762611-03-2022.xls',
#  '0944XXXXXXXXX762614-06-2022.pdf',
#  '1649424944_codeofconduct.pdf',
#  '6107030069.pdf',
#  '710579.jpg',
#  'AdmitCard-220310062539 (1).pdf',
#  'Adobe Scan 08-Mar-2022.pdf',
#  'AMAN 01.jpg',
#  'AMAN 02.jpg',
#  'Aman Kumar_CCR220105CR475256513.pdf',
#  'AMAN WBJEE.pdf',
#  'AMAN8210.jpg',
#  'AnyDesk.exe',
#  'Backup-codes-aman09092002 (1).txt',
#  'Backup-codes-aman09092002.txt',
#  'Bank stat 2022.xls',
#  'Bank statement 2021-2022.pdf',
#  'Biomolecules -01 _ Class Notes (1).pdf',
#  'Biomolecules -02 _ Class Notes (1).pdf',
#  'Biomolecules -03 _ Class Notes (1).pdf',
#  'bKc86m7.jpg',
#  'BraveBrowserSetup-FAZ287.exe',
#  'Capacitor 04 _ Class Notes.pdf',
#  'CFL_27122021_02012022 (1).pdf',
#  'CFL_27122021_02012022.pdf',
#  'Ch 02 Inverse Trigonometric Functions.pdf',
#  'Ch 04 Complex Number and Quraditic Equation.pdf',
# ...

# %%
pwd()
# Out:
# 'C:\\Users\\aman0\\File2026'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\aman0\\File2026'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\aman0\\File2026'

# %%
pwd()
# Out:
# 'C:\\Users\\aman0\\File2026'

# %%
os.mkdir("aman")

# %%
os.chdir("D://")

# %%
pwd()
# Out:
# 'D:\\'

# %%
os.chdir("C:\\Users\\aman0\\File2026")

# %%
pwd()
# Out:
# 'C:\\Users\\aman0\\File2026'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'aman',
#  'test.txt',
#  'test1.txt',
#  'test2.txt',
#  'test5.txt',
#  'text.txt',
#  'Untitled.ipynb']

# %%
if "test1.txt" in os.listdir():
    print("my file is available in this dir")
    f = open("test1.txt", "r+")
    print(f)
    for i in f:
        print(i)
else:
    print("no file is availbale ")
# Out:
# my file is available in this dir
# <_io.TextIOWrapper name='test1.txt' mode='r+' encoding='cp1252'>
# bhdwguy gweuygduwegkd weyuew

# %%
os.mkdir("aman")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[151], line 1
# ----> 1 os.mkdir("aman")
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'aman'

# %%
if not os.path.isdir("aman"):
    os.mkdir("aman")

# %%
os.rename("test1.txt", "xyz.txt")

# %%
f = open("test1.txt", "r+")
f.close()

# %%
os.rmdir("aman")

# %%
pwd()
# Out:
# 'C:\\Users\\aman0\\File2026'

# %%
os.mkdir("aman")

# %%
for i in os.listdir():

# %%
os.listdir()
# Out:
#   Cell In[165], line 1
#     os.listdir(//"aman")
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# 1. create a directory
# 2. create io text file and write some data in all txt at a time
# 3. read all the data from this dir/file print in console
# 4. hold all the data in a list
# 5. write all the data in a new file from a list
# 6. keep only a new file in present dir and move rest in new dir

# %%
pwd()
# Out:
# 'C:\\Users\\aman0\\File2026'

# %%
os.chdir('C:\\Users\\aman0\\File2026\\aman')

# %%
pwd()
# Out:
# 'C:\\Users\\aman0\\File2026\\aman'

# %%
pwd()
# Out:
# 'C:\\Users\\aman0\\File2026\\aman'

# %%
f = open("text1.txt", "w")

# %%
for i in range(13,23):
    f = open("text{}.txt".format(i), "w")
    f.write("Hello my name is anshu and ijdh uiwheuidh weihfuweg yfuwguy fgwygw")
    f.close()

# %%
pwd()
# Out:
# 'C:\\Users\\aman0\\File2026\\aman'

# %%
os.listdir()
# Out:
# ['text1.txt',
#  'text10.txt',
#  'text11.txt',
#  'text13.txt',
#  'text14.txt',
#  'text15.txt',
#  'text16.txt',
#  'text17.txt',
#  'text18.txt',
#  'text19.txt',
#  'text2.txt',
#  'text20.txt',
#  'text21.txt',
#  'text22.txt',
#  'text3.txt',
#  'text4.txt',
#  'text5.txt',
#  'text6.txt',
#  'text7.txt',
#  'text8.txt',
#  'text9.txt']

# %%
for i in range(25):
    f = open("text{}".format(i), "r")
    f.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[181], line 2
#       1 for i in range(25):
# ----> 2     f = open("text{}".format(i), "r")
#       3     f.read()
#
# File D:\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'text0'

# %% [markdown]
# 1. create a directory
# 2. create io text file and write some data in all txt at a time
# 3. read all the data from this dir/file print in console
# 4. hold all the data in a list
# 5. write all the data in a new file from a list
# 6. keep only a new file in present dir and move rest in new dir

# %%
os.mkdir("hardeep")

# %%
os.chdir('C:\\Users\\aman0\\File2026\\aman\\hardeep')

# %%
for i in range(1,11):
    f = open("text{}.txt".format(i),"w")
    f.write("This is a first file")
    f.close()

# %%
lst = os.listdir()
lst
for i in lst:
    f = open(i, "r")
    print(f.read())
    f.close()
# Out:
# This is a first file
# This is a first file
# This is a first file
# This is a first file
# This is a first file
# This is a first file
# This is a first file
# This is a first file
# This is a first file
# This is a first file

# %%
lst = os.listdir()
lst
ReadData = []
for i in range(1,11):
    f = open("text{}.txt".format(i),"r")
    ReadData.append(f.read())
    f.close()
ReadData
# Out:
# ['This is a first file',
#  'This is a first file',
#  'This is a first file',
#  'This is a first file',
#  'This is a first file',
#  'This is a first file',
#  'This is a first file',
#  'This is a first file',
#  'This is a first file',
#  'This is a first file']

# %%
f = open("NewFile.txt", "r+")
for x in ReadData:
    f.write(x)
    print(f.read())
    
f.close()
# Out:
# This is a first fileThis is a first fileThis is a first fileThis is a first fileThis is a first fileThis is a first fileThis is a first fileThis is a first fileThis is a first file

# %%
os.mkdir("hardeep")
os.chdir('C:\\Users\\aman0\\File2026\\hardeep')

for i in range(1,11):
    Fname = "test"+str{i}+".txt"
    f = open(Fname,"w")
    f.write("This is a first file")
    f.close()

lst = os.listdir()
lst
for i in lst:
    f = open(i, "r")
    print(f.read())
    f.close()

lst = os.listdir()
lst
ReadData = []
for i in range(1,11):
    f = open("text{}.txt".format(i),"r")
    ReadData.append(f.read())
    f.close()
ReadData

f = open("NewFile.txt", "w")
for x in ReadData:
    f.write(x)
f.close()

# %%
pwd()
# Out:
# 'C:\\Users\\aman0\\File2026\\aman\\hardeep'

# %%
os.listdir()
# Out:
# ['text1.txt',
#  'text10.txt',
#  'text2.txt',
#  'text3.txt',
#  'text4.txt',
#  'text5.txt',
#  'text6.txt',
#  'text7.txt',
#  'text8.txt',
#  'text9.txt']

# %%
os.listdir()
# Out:
# ['text1.txt',
#  'text10.txt',
#  'text2.txt',
#  'text3.txt',
#  'text4.txt',
#  'text5.txt',
#  'text6.txt',
#  'text7.txt',
#  'text8.txt',
#  'text9.txt']
