# %%
print("dhgwhejd)
# Out:
#   Cell In[1], line 1
#     print("dhgwhejd)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
def test(a,b):
    return a/b

# %%
test(2,0)
print("this is my code after test functio")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 test(2,0)
#       2 print("this is my code after test functio")
#
# Cell In[2], line 2, in test(a, b)
#       1 def test(a,b):
# ----> 2     return a/b
#
# ZeroDivisionError: division by zero

# %%
test(6,2)
# Out:
# 3.0

# %%
a= open("test.txt", 'r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 a= open("test.txt", 'r')
#
# File D:\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.txt'

# %%
try:
    a = open("test.txt", 'r')
except IOError as e:
    print("There is some issue in my code",e)
# Out:
# There is some issue in my code [Errno 2] No such file or directory: 'test.txt'

# %%
try:
    a = 5/0
except ArithmeticError as e:
    print("There is some issue in my code", e)
# Out:
# There is some issue in my code division by zero

# %%
try:
    a = 5/0
except:
    print("There is some issue in my code")
# Out:
# There is some issue in my code

# %%
try:
    a = int(input("enter the first number"))
    b = int(input("Enter the second number"))
    c = a/b
except ArithmeticError as e:
    print("There is some issue in my code", e)
    f = open("test.txt", 'w+')
    f.write("There is an issue")
    f.read()
    f.close()
else:
    print("This will execute try will execute with sucess")
    try:
        f = open("test.txt",'r')
    except:
        print("There is an issue with an internal try block")
# Out:
# enter the first number 5
# Enter the second number 0
# There is some issue in my code division by zero

# %%
l = [4,5,6,7,8,9,0]
#l[100]
t = (7,8,9,12,3,4,5,6)
print(t)
t[0] ="sudh"
# Out:
# (7, 8, 9, 12, 3, 4, 5, 6)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 5
#       3 t = (7,8,9,12,3,4,5,6)
#       4 print(t)
# ----> 5 t[0] ="sudh"
#
# TypeError: 'tuple' object does not support item assignment

# %%
try:
    l = [1,2,3,45,6,7,8,9,0]
    l[100]
except:
    print("There is an issue with my code")
    t = (4,5,6,7,8,9,0)
    print(t)
    try:
        t[0] = "aman"
        try:
            list(t)
            print(t)
        except:
            pass
    except:
        pass
else:
    print("There is no issue with my code")
# Out:
# There is an issue with my code
# (4, 5, 6, 7, 8, 9, 0)

# %%
try:
    f = open("test.txt", 'r')
finally:
    print("Finally i will execute in any case")
# Out:
# Finally i will execute in any case

# %%
try:
    f = open("test44", 'w+')
except:
    pass
else:
    print("else will execute if try will execute with suc")
finally:
    print("finally i will execute in any case")
    l = [2,3,4,5]
    l[0]
    try:
        print(l[0])
    except:
        pass
# Out:
# else will execute if try will execute with suc
# finally i will execute in any case
# 2

# %%
5/6
# Out:
# 0.8333333333333334

# %%
try:
    f = open("test3.txt", 'r')
except IOError as e:
    print("This is my error", e)
# Out:
# This is my error [Errno 2] No such file or directory: 'test3.txt'

# %%
def askforint():
    while True:
        try:
            a = int(input("Enter an integer"))
        except FileNotFoundError as e:
            print("This is my error msg", e)
        except IOError as e:
            print(e)
        except ValueError as e:
            print(e)
        else:
            print("Person has enterd a correct value")
            break
        finally:
            print("close the issue")

# %%
askforint()
# Out:
# Enter an integer dwedw
# invalid literal for int() with base 10: 'dwedw'
# close the issue
# Enter an integer 54
# Person has enterd a correct value
# close the issue

# %%
def askforint():
    while True:
        try:
            a = int(input("Enter an integer"))
            c = 8/a
        except FileNotFoundError as e:
            print("This is my error msg", e)
        except IOError as e:
            print(e)
        except ValueError as e:
            print(e)
        except Exception as e:
            print("This is a parent class",e)
        except ArithmeticError as e:
            print(e)
        
        except ZeroDivisionError as e:
            print(e)
        else:
            print("Person has enterd a correct value")
            break
        finally:
            print("close the issue")

# %%
askforint()
# Out:
# Enter an integer 0
# This is a parent class division by zero
# close the issue
# Enter an integer gjh
# invalid literal for int() with base 10: 'gjh'
# close the issue
# Enter an integer 9o
# invalid literal for int() with base 10: '9o'
# close the issue
# Enter an integer 9
# Person has enterd a correct value
# close the issue

# %%
# Create your exception

# %%
def create_your_exception(a):
    if a == 6:
        raise Exception(a)
    return a

# %%
a = create_your_exception(6)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 a = create_your_exception(6)
#
# Cell In[86], line 3, in create_your_exception(a)
#       1 def create_your_exception(a):
#       2     if a == 6:
# ----> 3         raise Exception(a)
#       4     return a
#
# Exception: 6

# %%
a
# Out:
# 5

# %%
def create_your_exception(a):
    if a == 6:
        raise Exception("error is ", a)
    else:
        print("Input is ok")
    return a

# %%
try:
    create_your_exception(6)
except Exception as e:
    print(e)
# Out:
# ('error is ', 6)

# %%
a
# Out:
# 7

# %%
def create_your_exception(a):
    if a > 6:
        raise Exception("error is ", a)
    else:
        print("Input is ok")
    return a

# %%
try:
    create_your_exception(10)
except Exception as e:
    print(e)
# Out:
# ('error is ', 10)

# %%
def create_your_exception(a):
    if a == "aman":
        raise Exception("error is ", a)
    else:
        print("Input is ok")
    return a

# %%
try:
    create_your_exception("aman")
except Exception as e:
    print(e)
# Out:
# ('error is ', 'aman')

# %% [markdown]
#  Create a directory test
# Into this directory create mo1.py file and write a logic to print all the even number
# in another python notebook file import mo1.py file and take input from user and try to handle all the edge case

# %%
import os

# %%
pwd
# Out:
# 'C:\\Users\\aman0\\test'

# %%
os.chdir("test")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 os.chdir("test")
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'test'

# %%
import mo1

# %%
mo1.check_prime()
# Out:
# Enter any number for check prime  jbdhxajd
# Enter the correct value invalid literal for int() with base 10: 'jbdhxajd'
